# %%
import argparse
import os
import matplotlib.pyplot as plt
from matplotlib.pyplot import show
import scipy.io
import scipy.misc
import numpy as np
import pandas as pd
import PIL
from PIL import ImageFont, ImageDraw, Image
import tensorflow as tf
from tensorflow.python.framework.ops import EagerTensor
from tensorflow.keras.models import load_model
from yad2k.models.keras_yolo import yolo_head
from yad2k.utils.utils import scale_boxes, read_classes, read_anchors, preprocess_image, draw_boxes, scale_boxes
# from yad2k.models.keras_yolo import yolo_head, yolo_boxes_to_corners, preprocess_true_boxes, yolo_loss, yolo_body

# %matplotlib inline

# %%
def yolo_filter_boxes(boxes, box_confidence, box_class_probs, threshold=0.6):
    
    x = 10
    y = tf.constant(100)
    box_scores = box_class_probs * box_confidence
    box_classes = tf.math.argmax(box_scores, axis=-1)
    box_class_scores = tf.math.reduce_max(box_scores, axis=-1)
    filtering_mask = (box_class_scores > threshold)
    
    scores = tf.boolean_mask(box_class_scores, filtering_mask)
    boxes = tf.boolean_mask(boxes, filtering_mask)
    classes = tf.boolean_mask(box_classes,filtering_mask)
    return scores, boxes, classes

# %%
# !export TF_CPP_MIN_LOG_LEVEL=2

# %%
# import os
# os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
tf.random.set_seed(10)
box_confidence = tf.random.normal([19, 19, 5, 1], mean=1, stddev=4, seed=1)
# box_confidence[:, :, 2, 0].shape
boxes = tf.random.normal([19, 19, 5, 4], mean=1, stddev=4, seed=1)
box_class_probs = tf.random.normal([19, 19, 5, 80], mean=1, stddev=4, seed=1)

scores, boxes, classes = yolo_filter_boxes(boxes, box_confidence, box_class_probs, threshold=0.5)
classes.shape
# Out:
# 2022-08-28 08:47:22.910689: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# TensorShape([1789])

# %%
-6.796674 * 3.2204947
# Out:
# -21.888652594627803

# %%
def iou(box1, box2):
    
    (box1_x1, box1_y1, box1_x2, box1_y2) = box1
    (box2_x1, box2_y1, box2_x2, box2_y2) = box2
    
    xi1 = max(box1_x1, box2_x1)
    yi1 = max(box1_y1, box2_y1)
    xi2 = min(box1_x2, box2_x2)
    yi2 = min(box1_y2, box2_y2)
    
    inter_width = max(0, yi2-yi1)
    inter_height = max(0, xi2-xi1)
    inter_area = inter_width * inter_height
    
    box1_area = (box1_x2 - box1_x1) * (box1_y2 - box1_y1)
    box2_area = (box2_x2 - box2_x1) * (box2_y2 - box2_y1)
    union_area = box1_area + box2_area - inter_area
    
    iou = inter_area / union_area
    return iou

# %%
box1 = (2, 1, 4, 3)
box2 = (1, 2, 3, 4)

print("iou for intersecting boxes = " + str(iou(box1, box2)))
# Out:
# iou for intersecting boxes = 0.14285714285714285

# %%
def yolo_non_max_suppression(scores, boxes, classes, max_boxes=10, iou_threshold=0.5):
    
    
    max_boxes_tensor = tf.Variable(max_boxes, dtype='int32')
    nms_indices = tf.image.non_max_suppression(boxes, scores, max_boxes, iou_threshold)
    scores = tf.gather(scores, nms_indices)
    boxes = tf.gather(boxes, nms_indices)
    classes = tf.gather(classes, nms_indices)
    
    return scores, boxes, classes

# %%
tf.random.set_seed(10)
scores = tf.random.normal([54,], mean=1, stddev=4, seed = 1)
# print(scores)
boxes = tf.random.normal([54, 4], mean=1, stddev=4, seed = 1)
classes = tf.random.normal([54,], mean=1, stddev=4, seed = 1)
scores, boxes, classes = yolo_non_max_suppression(scores, boxes, classes)

# print(max_boxes_tensor)
print("scores = " + str(scores))
print("boxes = " + str(boxes))
# print("classes[2] = " + str(classes[2].numpy()))
# print("scores.shape = " + str(scores.numpy().shape))
# print("boxes.shape = " + str(boxes.numpy().shape))
# print("classes.shape = " + str(classes.numpy().shape))
# Out:
# scores = tf.Tensor(
# [10.045049   8.779423   8.147684   7.2734113  6.5295115  4.758901
#   4.75377    4.2408733  4.213396   3.9896295], shape=(10,), dtype=float32)
# boxes = tf.Tensor(
# [[ 6.8292465   4.5420675   6.376947    0.08290124]
#  [ 2.3163939   3.367772   -4.257925   -0.6737312 ]
#  [ 6.0797963   3.743308    1.3914018  -0.34089637]
#  [ 1.8424486   1.5118144   0.67746973  0.02823198]
#  [-5.2856283   6.826084   12.549065    7.8252673 ]
#  [-0.5006654   1.6858735  -4.3660636   1.7608016 ]
#  [-0.4836073  -1.5442374  -0.92690074  0.40863764]
#  [ 3.4293325  -1.454927    5.490014   -0.57602644]
#  [ 1.5415473   2.496262    6.9025564  -2.0676918 ]
#  [ 8.448372    1.1546985   4.7752748   6.2906938 ]], shape=(10, 4), dtype=float32)

# %%
def yolo_boxes_to_corners(box_xy, box_wh):
    box_mins = box_xy - (box_wh / 2.)
    box_maxs = box_xy + (box_wh / 2.)
    return tf.keras.backend.concatenate([
        box_mins[..., 1:2], #y_min
        box_mins[..., 0:1], #x_min
        box_maxs[..., 1:2], #y_max
        box_mins[..., 0:1], #y_max
    ])

# %%
# c = np.array([5.3776083 , 0.77948886])
# b = np.array([5.3776083 , 0.77948886])
# a = yolo_boxes_to_corners(c, b)
# a

# %%
def yolo_eval(yolo_outputs, image_shape=(720, 1280), max_boxes=10, score_threshold=0.6, iou_threshold=.5):
    
    box_xy, box_wh, box_confidence, box_class_probs = yolo_outputs
    boxes = yolo_boxes_to_corners(box_xy, box_wh)
    scores, boxes, classes = yolo_filter_boxes(boxes, box_confidence, box_class_probs, score_threshold)
    boxes = scale_boxes(boxes, image_shape)
    scores, boxes, classes = yolo_non_max_suppression(scores, boxes, classes, max_boxes, iou_threshold)
    
    return scores, boxes, classes

# %%
tf.random.set_seed(10)
yolo_outputs = (tf.random.normal([19, 19, 5, 2], mean=1, stddev=4, seed = 1),
                tf.random.normal([19, 19, 5, 2], mean=1, stddev=4, seed = 1),
                tf.random.normal([19, 19, 5, 1], mean=1, stddev=4, seed = 1),
                tf.random.normal([19, 19, 5, 80], mean=1, stddev=4, seed = 1))
scores, boxes, classes = yolo_eval(yolo_outputs)
print("scores[2] = " + str(scores[2].numpy()))
print("boxes[2] = " + str(boxes[2].numpy()))
print("classes[2] = " + str(classes[2].numpy()))
print("scores.shape = " + str(scores.numpy().shape))
print("boxes.shape = " + str(boxes.numpy().shape))
print("classes.shape = " + str(classes.numpy().shape))
# Out:
# scores[2] = 171.60194
# boxes[2] = [-1240.3483 -3212.5881  -645.78   -3212.5881]
# classes[2] = 16
# scores.shape = (10,)
# boxes.shape = (10, 4)
# classes.shape = (10,)

# %%
from keras import backend as K
sess = K.get_session()

# %%
class_names = read_classes("model_data/coco_classes.txt")
anchors = read_anchors("model_data/yolo_anchors.txt")
image_shape = (720., 1280.)

# %%
yolo_model = load_model("model_data/yolo.h5", compile=False)

# %%
yolo_model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  conv2d_1 (Conv2D)              (None, None, None,   864         ['input_1[0][0]']
#                                 32)
#
#  batch_normalization_1 (BatchNo  (None, None, None,   128        ['conv2d_1[0][0]']
#  rmalization)                   32)
#
#  leaky_re_lu_1 (LeakyReLU)      (None, None, None,   0           ['batch_normalization_1[0][0]']
#                                 32)
#
#  zero_padding2d_1 (ZeroPadding2  (None, None, None,   0          ['leaky_re_lu_1[0][0]']
#  D)                             32)
#
#  conv2d_2 (Conv2D)              (None, None, None,   18432       ['zero_padding2d_1[0][0]']
#                                 64)
#
#  batch_normalization_2 (BatchNo  (None, None, None,   256        ['conv2d_2[0][0]']
#  rmalization)                   64)
#
#  leaky_re_lu_2 (LeakyReLU)      (None, None, None,   0           ['batch_normalization_2[0][0]']
#                                 64)
#
#  conv2d_3 (Conv2D)              (None, None, None,   2048        ['leaky_re_lu_2[0][0]']
#                                 32)
#
#  batch_normalization_3 (BatchNo  (None, None, None,   128        ['conv2d_3[0][0]']
#  rmalization)                   32)
#
#  leaky_re_lu_3 (LeakyReLU)      (None, None, None,   0           ['batch_normalization_3[0][0]']
#                                 32)
#
#  conv2d_4 (Conv2D)              (None, None, None,   18432       ['leaky_re_lu_3[0][0]']
#                                 64)
#
#  batch_normalization_4 (BatchNo  (None, None, None,   256        ['conv2d_4[0][0]']
#  rmalization)                   64)
#
#  leaky_re_lu_4 (LeakyReLU)      (None, None, None,   0           ['batch_normalization_4[0][0]']
#                                 64)
#
#  add_1 (Add)                    (None, None, None,   0           ['leaky_re_lu_2[0][0]',
#                                 64)                               'leaky_re_lu_4[0][0]']
#
#  zero_padding2d_2 (ZeroPadding2  (None, None, None,   0          ['add_1[0][0]']
#  D)                             64)
#
#  conv2d_5 (Conv2D)              (None, None, None,   73728       ['zero_padding2d_2[0][0]']
#                                 128)
#
#  batch_normalization_5 (BatchNo  (None, None, None,   512        ['conv2d_5[0][0]']
#  rmalization)                   128)
#
#  leaky_re_lu_5 (LeakyReLU)      (None, None, None,   0           ['batch_normalization_5[0][0]']
#                                 128)
#
#  conv2d_6 (Conv2D)              (None, None, None,   8192        ['leaky_re_lu_5[0][0]']
#                                 64)
#
#  batch_normalization_6 (BatchNo  (None, None, None,   256        ['conv2d_6[0][0]']
#  rmalization)                   64)
#
#  leaky_re_lu_6 (LeakyReLU)      (None, None, None,   0           ['batch_normalization_6[0][0]']
#                                 64)
#
#  conv2d_7 (Conv2D)              (None, None, None,   73728       ['leaky_re_lu_6[0][0]']
#                                 128)
#
#  batch_normalization_7 (BatchNo  (None, None, None,   512        ['conv2d_7[0][0]']
#  rmalization)                   128)
#
#  leaky_re_lu_7 (LeakyReLU)      (None, None, None,   0           ['batch_normalization_7[0][0]']
#                                 128)
#
#  add_2 (Add)                    (None, None, None,   0           ['leaky_re_lu_5[0][0]',
#                                 128)                              'leaky_re_lu_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, None, None,   8192        ['add_2[0][0]']
#                                 64)
#
#  batch_normalization_8 (BatchNo  (None, None, None,   256        ['conv2d_8[0][0]']
#  rmalization)                   64)
#
#  leaky_re_lu_8 (LeakyReLU)      (None, None, None,   0           ['batch_normalization_8[0][0]']
#                                 64)
#
#  conv2d_9 (Conv2D)              (None, None, None,   73728       ['leaky_re_lu_8[0][0]']
#                                 128)
#
#  batch_normalization_9 (BatchNo  (None, None, None,   512        ['conv2d_9[0][0]']
#  rmalization)                   128)
#
#  leaky_re_lu_9 (LeakyReLU)      (None, None, None,   0           ['batch_normalization_9[0][0]']
#                                 128)
#
#  add_3 (Add)                    (None, None, None,   0           ['add_2[0][0]',
#                                 128)                              'leaky_re_lu_9[0][0]']
#
#  zero_padding2d_3 (ZeroPadding2  (None, None, None,   0          ['add_3[0][0]']
#  D)                             128)
#
#  conv2d_10 (Conv2D)             (None, None, None,   294912      ['zero_padding2d_3[0][0]']
#                                 256)
#
#  batch_normalization_10 (BatchN  (None, None, None,   1024       ['conv2d_10[0][0]']
#  ormalization)                  256)
#
#  leaky_re_lu_10 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_10[0][0]']
#                                 256)
#
#  conv2d_11 (Conv2D)             (None, None, None,   32768       ['leaky_re_lu_10[0][0]']
#                                 128)
#
#  batch_normalization_11 (BatchN  (None, None, None,   512        ['conv2d_11[0][0]']
#  ormalization)                  128)
#
#  leaky_re_lu_11 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_11[0][0]']
#                                 128)
#
#  conv2d_12 (Conv2D)             (None, None, None,   294912      ['leaky_re_lu_11[0][0]']
#                                 256)
#
#  batch_normalization_12 (BatchN  (None, None, None,   1024       ['conv2d_12[0][0]']
#  ormalization)                  256)
#
#  leaky_re_lu_12 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_12[0][0]']
#                                 256)
#
#  add_4 (Add)                    (None, None, None,   0           ['leaky_re_lu_10[0][0]',
#                                 256)                              'leaky_re_lu_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, None, None,   32768       ['add_4[0][0]']
#                                 128)
#
#  batch_normalization_13 (BatchN  (None, None, None,   512        ['conv2d_13[0][0]']
#  ormalization)                  128)
#
#  leaky_re_lu_13 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_13[0][0]']
#                                 128)
#
#  conv2d_14 (Conv2D)             (None, None, None,   294912      ['leaky_re_lu_13[0][0]']
#                                 256)
#
#  batch_normalization_14 (BatchN  (None, None, None,   1024       ['conv2d_14[0][0]']
#  ormalization)                  256)
#
#  leaky_re_lu_14 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_14[0][0]']
#                                 256)
#
#  add_5 (Add)                    (None, None, None,   0           ['add_4[0][0]',
#                                 256)                              'leaky_re_lu_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, None, None,   32768       ['add_5[0][0]']
#                                 128)
#
#  batch_normalization_15 (BatchN  (None, None, None,   512        ['conv2d_15[0][0]']
#  ormalization)                  128)
#
#  leaky_re_lu_15 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_15[0][0]']
#                                 128)
#
#  conv2d_16 (Conv2D)             (None, None, None,   294912      ['leaky_re_lu_15[0][0]']
#                                 256)
#
#  batch_normalization_16 (BatchN  (None, None, None,   1024       ['conv2d_16[0][0]']
#  ormalization)                  256)
#
#  leaky_re_lu_16 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_16[0][0]']
#                                 256)
#
#  add_6 (Add)                    (None, None, None,   0           ['add_5[0][0]',
#                                 256)                              'leaky_re_lu_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, None, None,   32768       ['add_6[0][0]']
#                                 128)
#
#  batch_normalization_17 (BatchN  (None, None, None,   512        ['conv2d_17[0][0]']
#  ormalization)                  128)
#
#  leaky_re_lu_17 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_17[0][0]']
#                                 128)
#
#  conv2d_18 (Conv2D)             (None, None, None,   294912      ['leaky_re_lu_17[0][0]']
#                                 256)
#
#  batch_normalization_18 (BatchN  (None, None, None,   1024       ['conv2d_18[0][0]']
#  ormalization)                  256)
#
#  leaky_re_lu_18 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_18[0][0]']
#                                 256)
#
#  add_7 (Add)                    (None, None, None,   0           ['add_6[0][0]',
#                                 256)                              'leaky_re_lu_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, None, None,   32768       ['add_7[0][0]']
#                                 128)
#
#  batch_normalization_19 (BatchN  (None, None, None,   512        ['conv2d_19[0][0]']
#  ormalization)                  128)
#
#  leaky_re_lu_19 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_19[0][0]']
#                                 128)
#
#  conv2d_20 (Conv2D)             (None, None, None,   294912      ['leaky_re_lu_19[0][0]']
#                                 256)
#
#  batch_normalization_20 (BatchN  (None, None, None,   1024       ['conv2d_20[0][0]']
#  ormalization)                  256)
#
#  leaky_re_lu_20 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_20[0][0]']
#                                 256)
#
#  add_8 (Add)                    (None, None, None,   0           ['add_7[0][0]',
#                                 256)                              'leaky_re_lu_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, None, None,   32768       ['add_8[0][0]']
#                                 128)
#
#  batch_normalization_21 (BatchN  (None, None, None,   512        ['conv2d_21[0][0]']
#  ormalization)                  128)
#
#  leaky_re_lu_21 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_21[0][0]']
#                                 128)
#
#  conv2d_22 (Conv2D)             (None, None, None,   294912      ['leaky_re_lu_21[0][0]']
#                                 256)
#
#  batch_normalization_22 (BatchN  (None, None, None,   1024       ['conv2d_22[0][0]']
#  ormalization)                  256)
#
#  leaky_re_lu_22 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_22[0][0]']
#                                 256)
#
#  add_9 (Add)                    (None, None, None,   0           ['add_8[0][0]',
#                                 256)                              'leaky_re_lu_22[0][0]']
#
#  conv2d_23 (Conv2D)             (None, None, None,   32768       ['add_9[0][0]']
#                                 128)
#
#  batch_normalization_23 (BatchN  (None, None, None,   512        ['conv2d_23[0][0]']
#  ormalization)                  128)
#
#  leaky_re_lu_23 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_23[0][0]']
#                                 128)
#  conv2d_24 (Conv2D)             (None, None, None,   294912      ['leaky_re_lu_23[0][0]']
#                                 256)
#
#  batch_normalization_24 (BatchN  (None, None, None,   1024       ['conv2d_24[0][0]']
#  ormalization)                  256)
#
#  leaky_re_lu_24 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_24[0][0]']
#                                 256)
#
#  add_10 (Add)                   (None, None, None,   0           ['add_9[0][0]',
#                                 256)                              'leaky_re_lu_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, None, None,   32768       ['add_10[0][0]']
#                                 128)
#
#  batch_normalization_25 (BatchN  (None, None, None,   512        ['conv2d_25[0][0]']
#  ormalization)                  128)
#
#  leaky_re_lu_25 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_25[0][0]']
#                                 128)
#
#  conv2d_26 (Conv2D)             (None, None, None,   294912      ['leaky_re_lu_25[0][0]']
#                                 256)
#
#  batch_normalization_26 (BatchN  (None, None, None,   1024       ['conv2d_26[0][0]']
#  ormalization)                  256)
#
#  leaky_re_lu_26 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_26[0][0]']
#                                 256)
#
#  add_11 (Add)                   (None, None, None,   0           ['add_10[0][0]',
#                                 256)                              'leaky_re_lu_26[0][0]']
#
#  zero_padding2d_4 (ZeroPadding2  (None, None, None,   0          ['add_11[0][0]']
#  D)                             256)
#
#  conv2d_27 (Conv2D)             (None, None, None,   1179648     ['zero_padding2d_4[0][0]']
#                                 512)
#
#  batch_normalization_27 (BatchN  (None, None, None,   2048       ['conv2d_27[0][0]']
#  ormalization)                  512)
#
#  leaky_re_lu_27 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_27[0][0]']
#                                 512)
#
#  conv2d_28 (Conv2D)             (None, None, None,   131072      ['leaky_re_lu_27[0][0]']
#                                 256)
#
#  batch_normalization_28 (BatchN  (None, None, None,   1024       ['conv2d_28[0][0]']
#  ormalization)                  256)
#
#  leaky_re_lu_28 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_28[0][0]']
#                                 256)
#
#  conv2d_29 (Conv2D)             (None, None, None,   1179648     ['leaky_re_lu_28[0][0]']
#                                 512)
#
#  batch_normalization_29 (BatchN  (None, None, None,   2048       ['conv2d_29[0][0]']
#  ormalization)                  512)
#
#  leaky_re_lu_29 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_29[0][0]']
#                                 512)
#
#  add_12 (Add)                   (None, None, None,   0           ['leaky_re_lu_27[0][0]',
#                                 512)                              'leaky_re_lu_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, None, None,   131072      ['add_12[0][0]']
#                                 256)
#
#  batch_normalization_30 (BatchN  (None, None, None,   1024       ['conv2d_30[0][0]']
#  ormalization)                  256)
#
#  leaky_re_lu_30 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_30[0][0]']
#                                 256)
#
#  conv2d_31 (Conv2D)             (None, None, None,   1179648     ['leaky_re_lu_30[0][0]']
#                                 512)
#
#  batch_normalization_31 (BatchN  (None, None, None,   2048       ['conv2d_31[0][0]']
#  ormalization)                  512)
#
#  leaky_re_lu_31 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_31[0][0]']
#                                 512)
#
#  add_13 (Add)                   (None, None, None,   0           ['add_12[0][0]',
#                                 512)                              'leaky_re_lu_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, None, None,   131072      ['add_13[0][0]']
#                                 256)
#
#  batch_normalization_32 (BatchN  (None, None, None,   1024       ['conv2d_32[0][0]']
#  ormalization)                  256)
#
#  leaky_re_lu_32 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_32[0][0]']
#                                 256)
#
#  conv2d_33 (Conv2D)             (None, None, None,   1179648     ['leaky_re_lu_32[0][0]']
#                                 512)
#
#  batch_normalization_33 (BatchN  (None, None, None,   2048       ['conv2d_33[0][0]']
#  ormalization)                  512)
#
#  leaky_re_lu_33 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_33[0][0]']
#                                 512)
#
#  add_14 (Add)                   (None, None, None,   0           ['add_13[0][0]',
#                                 512)                              'leaky_re_lu_33[0][0]']
#
#  conv2d_34 (Conv2D)             (None, None, None,   131072      ['add_14[0][0]']
#                                 256)
#
#  batch_normalization_34 (BatchN  (None, None, None,   1024       ['conv2d_34[0][0]']
#  ormalization)                  256)
#
#  leaky_re_lu_34 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_34[0][0]']
#                                 256)
#
#  conv2d_35 (Conv2D)             (None, None, None,   1179648     ['leaky_re_lu_34[0][0]']
#                                 512)
#
#  batch_normalization_35 (BatchN  (None, None, None,   2048       ['conv2d_35[0][0]']
#  ormalization)                  512)
#
#  leaky_re_lu_35 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_35[0][0]']
#                                 512)
#
#  add_15 (Add)                   (None, None, None,   0           ['add_14[0][0]',
#                                 512)                              'leaky_re_lu_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, None, None,   131072      ['add_15[0][0]']
#                                 256)
#
#  batch_normalization_36 (BatchN  (None, None, None,   1024       ['conv2d_36[0][0]']
#  ormalization)                  256)
#
#  leaky_re_lu_36 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_36[0][0]']
#                                 256)
#
#  conv2d_37 (Conv2D)             (None, None, None,   1179648     ['leaky_re_lu_36[0][0]']
#                                 512)
#
#  batch_normalization_37 (BatchN  (None, None, None,   2048       ['conv2d_37[0][0]']
#  ormalization)                  512)
#
#  leaky_re_lu_37 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_37[0][0]']
#                                 512)
#
#  add_16 (Add)                   (None, None, None,   0           ['add_15[0][0]',
#                                 512)                              'leaky_re_lu_37[0][0]']
#
#  conv2d_38 (Conv2D)             (None, None, None,   131072      ['add_16[0][0]']
#                                 256)
#
#  batch_normalization_38 (BatchN  (None, None, None,   1024       ['conv2d_38[0][0]']
#  ormalization)                  256)
#
#  leaky_re_lu_38 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_38[0][0]']
#                                 256)
#
#  conv2d_39 (Conv2D)             (None, None, None,   1179648     ['leaky_re_lu_38[0][0]']
#                                 512)
#
#  batch_normalization_39 (BatchN  (None, None, None,   2048       ['conv2d_39[0][0]']
#  ormalization)                  512)
#
#  leaky_re_lu_39 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_39[0][0]']
#                                 512)
#
#  add_17 (Add)                   (None, None, None,   0           ['add_16[0][0]',
#                                 512)                              'leaky_re_lu_39[0][0]']
#
#  conv2d_40 (Conv2D)             (None, None, None,   131072      ['add_17[0][0]']
#                                 256)
#
#  batch_normalization_40 (BatchN  (None, None, None,   1024       ['conv2d_40[0][0]']
#  ormalization)                  256)
#
#  leaky_re_lu_40 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_40[0][0]']
#                                 256)
#
#  conv2d_41 (Conv2D)             (None, None, None,   1179648     ['leaky_re_lu_40[0][0]']
#                                 512)
#
#  batch_normalization_41 (BatchN  (None, None, None,   2048       ['conv2d_41[0][0]']
#  ormalization)                  512)
#
#  leaky_re_lu_41 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_41[0][0]']
#                                 512)
#
#  add_18 (Add)                   (None, None, None,   0           ['add_17[0][0]',
#                                 512)                              'leaky_re_lu_41[0][0]']
#
#  conv2d_42 (Conv2D)             (None, None, None,   131072      ['add_18[0][0]']
#                                 256)
#
#  batch_normalization_42 (BatchN  (None, None, None,   1024       ['conv2d_42[0][0]']
#  ormalization)                  256)
#
#  leaky_re_lu_42 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_42[0][0]']
#                                 256)
#
#  conv2d_43 (Conv2D)             (None, None, None,   1179648     ['leaky_re_lu_42[0][0]']
#                                 512)
#
#  batch_normalization_43 (BatchN  (None, None, None,   2048       ['conv2d_43[0][0]']
#  ormalization)                  512)
#
#  leaky_re_lu_43 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_43[0][0]']
#                                 512)
#
#  add_19 (Add)                   (None, None, None,   0           ['add_18[0][0]',
#                                 512)                              'leaky_re_lu_43[0][0]']
#
#  zero_padding2d_5 (ZeroPadding2  (None, None, None,   0          ['add_19[0][0]']
#  D)                             512)
#
#  conv2d_44 (Conv2D)             (None, None, None,   4718592     ['zero_padding2d_5[0][0]']
#                                 1024)
#
#  batch_normalization_44 (BatchN  (None, None, None,   4096       ['conv2d_44[0][0]']
#  ormalization)                  1024)
#
#  leaky_re_lu_44 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_44[0][0]']
#                                 1024)
#
#  conv2d_45 (Conv2D)             (None, None, None,   524288      ['leaky_re_lu_44[0][0]']
#                                 512)
#
#  batch_normalization_45 (BatchN  (None, None, None,   2048       ['conv2d_45[0][0]']
#  ormalization)                  512)
#
#  leaky_re_lu_45 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_45[0][0]']
#                                 512)
#
#  conv2d_46 (Conv2D)             (None, None, None,   4718592     ['leaky_re_lu_45[0][0]']
#                                 1024)
#
#  batch_normalization_46 (BatchN  (None, None, None,   4096       ['conv2d_46[0][0]']
# ...
#
#  leaky_re_lu_57 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_57[0][0]']
#                                 512)
#
#  conv2d_60 (Conv2D)             (None, None, None,   131072      ['leaky_re_lu_57[0][0]']
#                                 256)
#
#  batch_normalization_59 (BatchN  (None, None, None,   1024       ['conv2d_60[0][0]']
#  ormalization)                  256)
#
#  leaky_re_lu_59 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_59[0][0]']
#                                 256)
#
#  up_sampling2d_1 (UpSampling2D)  (None, None, None,   0          ['leaky_re_lu_59[0][0]']
#                                 256)
#
#  concatenate_1 (Concatenate)    (None, None, None,   0           ['up_sampling2d_1[0][0]',
#                                 768)                              'add_19[0][0]']
#
#  conv2d_61 (Conv2D)             (None, None, None,   196608      ['concatenate_1[0][0]']
#                                 256)
#
#  batch_normalization_60 (BatchN  (None, None, None,   1024       ['conv2d_61[0][0]']
#  ormalization)                  256)
#
#  leaky_re_lu_60 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_60[0][0]']
#                                 256)
#
#  conv2d_62 (Conv2D)             (None, None, None,   1179648     ['leaky_re_lu_60[0][0]']
#                                 512)
#
#  batch_normalization_61 (BatchN  (None, None, None,   2048       ['conv2d_62[0][0]']
#  ormalization)                  512)
#
#  leaky_re_lu_61 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_61[0][0]']
#                                 512)
#
#  conv2d_63 (Conv2D)             (None, None, None,   131072      ['leaky_re_lu_61[0][0]']
#                                 256)
#
#  batch_normalization_62 (BatchN  (None, None, None,   1024       ['conv2d_63[0][0]']
#  ormalization)                  256)
#
#  leaky_re_lu_62 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_62[0][0]']
#                                 256)
#
#  conv2d_64 (Conv2D)             (None, None, None,   1179648     ['leaky_re_lu_62[0][0]']
#                                 512)
#
#  batch_normalization_63 (BatchN  (None, None, None,   2048       ['conv2d_64[0][0]']
#  ormalization)                  512)
#
#  leaky_re_lu_63 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_63[0][0]']
#                                 512)
#
#  conv2d_65 (Conv2D)             (None, None, None,   131072      ['leaky_re_lu_63[0][0]']
#                                 256)
#
#  batch_normalization_64 (BatchN  (None, None, None,   1024       ['conv2d_65[0][0]']
#  ormalization)                  256)
#
#  leaky_re_lu_64 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_64[0][0]']
#                                 256)
#
#  conv2d_68 (Conv2D)             (None, None, None,   32768       ['leaky_re_lu_64[0][0]']
#                                 128)
#
#  batch_normalization_66 (BatchN  (None, None, None,   512        ['conv2d_68[0][0]']
#  ormalization)                  128)
#
#  leaky_re_lu_66 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_66[0][0]']
#                                 128)
#
#  up_sampling2d_2 (UpSampling2D)  (None, None, None,   0          ['leaky_re_lu_66[0][0]']
#                                 128)
#
#  concatenate_2 (Concatenate)    (None, None, None,   0           ['up_sampling2d_2[0][0]',
#                                 384)                              'add_11[0][0]']
#
#  conv2d_69 (Conv2D)             (None, None, None,   49152       ['concatenate_2[0][0]']
#                                 128)
#
#  batch_normalization_67 (BatchN  (None, None, None,   512        ['conv2d_69[0][0]']
#  ormalization)                  128)
#
#  leaky_re_lu_67 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_67[0][0]']
#                                 128)
#
#  conv2d_70 (Conv2D)             (None, None, None,   294912      ['leaky_re_lu_67[0][0]']
#                                 256)
#
#  batch_normalization_68 (BatchN  (None, None, None,   1024       ['conv2d_70[0][0]']
#  ormalization)                  256)
#
#  leaky_re_lu_68 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_68[0][0]']
#                                 256)
#
#  conv2d_71 (Conv2D)             (None, None, None,   32768       ['leaky_re_lu_68[0][0]']
#                                 128)
#
#  batch_normalization_69 (BatchN  (None, None, None,   512        ['conv2d_71[0][0]']
#  ormalization)                  128)
#
#  leaky_re_lu_69 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_69[0][0]']
#                                 128)
#
#  conv2d_72 (Conv2D)             (None, None, None,   294912      ['leaky_re_lu_69[0][0]']
#                                 256)
#
#  batch_normalization_70 (BatchN  (None, None, None,   1024       ['conv2d_72[0][0]']
#  ormalization)                  256)
#
#  leaky_re_lu_70 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_70[0][0]']
#                                 256)
#
#  conv2d_73 (Conv2D)             (None, None, None,   32768       ['leaky_re_lu_70[0][0]']
#                                 128)
#
#  batch_normalization_71 (BatchN  (None, None, None,   512        ['conv2d_73[0][0]']
#  ormalization)                  128)
#
#  leaky_re_lu_71 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_71[0][0]']
#                                 128)
#
#  conv2d_58 (Conv2D)             (None, None, None,   4718592     ['leaky_re_lu_57[0][0]']
#                                 1024)
#
#  conv2d_66 (Conv2D)             (None, None, None,   1179648     ['leaky_re_lu_64[0][0]']
#                                 512)
#
#  conv2d_74 (Conv2D)             (None, None, None,   294912      ['leaky_re_lu_71[0][0]']
#                                 256)
#
#  batch_normalization_58 (BatchN  (None, None, None,   4096       ['conv2d_58[0][0]']
#  ormalization)                  1024)
#
#  batch_normalization_65 (BatchN  (None, None, None,   2048       ['conv2d_66[0][0]']
#  ormalization)                  512)
#
#  batch_normalization_72 (BatchN  (None, None, None,   1024       ['conv2d_74[0][0]']
#  ormalization)                  256)
#
#  leaky_re_lu_58 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_58[0][0]']
#                                 1024)
#
#  leaky_re_lu_65 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_65[0][0]']
#                                 512)
#  leaky_re_lu_72 (LeakyReLU)     (None, None, None,   0           ['batch_normalization_72[0][0]']
#                                 256)
#
#  conv2d_59 (Conv2D)             (None, None, None,   261375      ['leaky_re_lu_58[0][0]']
#                                 255)
#
#  conv2d_67 (Conv2D)             (None, None, None,   130815      ['leaky_re_lu_65[0][0]']
#                                 255)
#
#  conv2d_75 (Conv2D)             (None, None, None,   65535       ['leaky_re_lu_72[0][0]']
#                                 255)
#
# ==================================================================================================
# Total params: 62,001,757
# Trainable params: 61,949,149
# Non-trainable params: 52,608
# __________________________________________________________________________________________________

# %%
yolo_model.output[0]
# Out:
# <KerasTensor: shape=(None, None, None, 255) dtype=float32 (created by layer 'conv2d_59')>

# %%
yolo_outputs = yolo_head(yolo_model.output[0], anchors, len(class_names))

# %%
import numpy as np
a=np.array([[1, 3, 3],[1, 2, 2]])
a[:, :1]
# Out:
# array([[1],
#        [1]])

# %%
scores, boxes, classes = yolo_eval(yolo_outputs, image_shape)

# %%
def predict(sess, image_file):
    image, image_data = preprocess_image('images/', image_file, model_image_size=(608, 608))
    out_scores, out_boxes, out_classes = sess.run([scores, boxes, classes], feed_dict={yolo_model.input: image_data, K.learning_phase(): 0})
    print('Found {} boxes for {}'.format(len(out_boxes), image_file))
    colors = generate_colors(class_names)
    draw_boxes(image, out_score, out_boxes, out_classes, class_names, colors)
    image.save(os.path.join("out", image_file))
    output_image = scipy.misc.imread(os.path.join("out", image_file))
    imshow(output_image)
    
    return out_scores, out_boxes, out_classes

# %% [markdown]
# Python *args
# As in the above example we are not sure about the number of arguments that can be passed to a function. Python has *args which allow us to pass the variable number of non keyword arguments to function.
#
# Python **kwargs
# Python passes variable length non keyword argument to function using *args but we cannot use this to pass keyword argument. For this problem Python has got a solution called **kwargs, it allows us to pass the variable length of keyword arguments to the function.

# %%
out_scores, out_boxes, out_classes = predict(sess, "test.jpg")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/11/9_0bxr017h92r81nbztybj540000gn/T/ipykernel_1049/1983073588.py in <module>
# ----> 1 out_scores, out_boxes, out_classes = predict(sess, "test.jpg")
#
# /var/folders/11/9_0bxr017h92r81nbztybj540000gn/T/ipykernel_1049/558665147.py in predict(sess, image_file)
#       1 def predict(sess, image_file):
# ----> 2     image, image_data = preprocess_image('images/', image_file, model_image_size=(608, 608))
#       3     out_scores, out_boxes, out_classes = sess.run([scores, boxes, classes], feed_dict={yolo_model.input: image_data, K.learning_phase(): 0})
#       4     print('Found {} boxes for {}'.format(len(out_boxes), image_file))
#       5     colors = generate_colors(class_names)
#
# TypeError: preprocess_image() got multiple values for argument 'model_image_size'
